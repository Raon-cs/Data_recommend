# %%
from flask import Flask, request, render_template
import clftask
import clftask2


data, data_link = clftask.gibon()
app=Flask(__name__)

@app.route("/")
@app.route("/home")
@app.route("/home.html")
def main():
    return render_template('home1.html')

@app.route("/introduce")
def introduce():
    return render_template('introduce2.html')

@app.route("/Services")
@app.route("/Services.html")
def Services():
    return render_template('Services2.html')

@app.route("/model1_1.html")
def model1():
    return render_template('model1_1.html')

@app.route("/model2_1.html")
def model2():
    return render_template('model2_1.html')

@app.route('/model1_1', methods = ['POST'])
def model1_1():
    if request.method == 'POST':
        name = request.form['name3']
        list12,num12 = clftask.all_career(name)
        if num12 == 0:
            total, time = clftask2.all_next(list12,data,data_link)
            d2 = list12
            a11 = total[0][0]
            a12 = total[0][1]
            b11 = total[1][0]
            b12 = total[1][1]
            c11 = total[2][0]
            c12 = total[2][1]
            s1 = total[0][2]
            s2 = total[1][2]
            s3 = total[2][2]
            d1 = str(round(time)) +'s'
            return render_template('result_test_11.html', a11=a11,a12 = a12, b11=b11, b12=b12,c11=c11,c12=c12, user_input = name, d2 = d2, s1=s1,s2=s2,s3=s3, d1=d1)
        else:
            return render_template('model1_2.html')
            

@app.route('/model1_2', methods = ['POST'])
def model1_2():
    if request.method == 'POST':
        name1 = request.form['name4']
        list12 = clftask.all_nocareer(name1)
        total, time = clftask2.all_next(list12,data,data_link)
        d2 = list12
        a11 = total[0][0]
        a12 = total[0][1]
        b11 = total[1][0]
        b12 = total[1][1]
        c11 = total[2][0]
        c12 = total[2][1]
        s1 = total[0][2]
        s2 = total[1][2]
        s3 = total[2][2]
        d1 = str(round(time)) +'s'
        return render_template('result_test_13.html', a11=a11,a12 = a12, b11=b11, b12=b12,c11=c11,c12=c12, d2=d2, s1=s1,s2=s2,s3=s3, d1=d1)

@app.route('/model2_1', methods = ['POST'])
def model2_1():
    if request.method == 'POST':
        name = request.form['name']
        list12,num12 = clftask.all_career(name)
        if num12 == 0:
            total, time = clftask.all_next(list12,data,data_link)
            d2 = list12
            a11 = total[0][0]
            a12 = total[0][1]
            b11 = total[1][0]
            b12 = total[1][1]
            c11 = total[2][0]
            c12 = total[2][1]
            s1 = total[0][2]
            s2 = total[1][2]
            s3 = total[2][2]
            d1 = str(round(time)) +'s'
            return render_template('result_test_12.html', a11=a11,a12 = a12, b11=b11, b12=b12,c11=c11,c12=c12, user_input = name, d2= d2, s1=s1,s2=s2,s3=s3,d1=d1)
        else:
            return render_template('model2_2.html')
            

@app.route('/model2_2', methods = ['POST'])
def model2_2():
    if request.method == 'POST':
        name1 = request.form['name1']
        list12 = clftask.all_nocareer(name1)
        total, time = clftask.all_next(list12,data,data_link)
        d2 = list12
        a11 = total[0][0]
        a12 = total[0][1]
        b11 = total[1][0]
        b12 = total[1][1]
        c11 = total[2][0]
        c12 = total[2][1]
        s1 = total[0][2]
        s2 = total[1][2]
        s3 = total[2][2]
        d1 = str(round(time)) +'s'
        return render_template('result_test_14.html', a11=a11,a12 = a12, b11=b11, b12=b12,c11=c11,c12=c12, d2 =d2, s1=s1,s2=s2,s3=s3, d1=d1)
        
if __name__ == '__main__':
    app.run()
# Out:
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
